# %%
import numpy as np
import cv2

# %%
arr = np.zeros((100,100))
arr = cv2.circle(arr, (50,50), 20, 1, -1)

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(arr)

# %%
arr.dtype
# Out:
# dtype('float64')

# %%
arr = (arr/255).astype(np.float32)

# %%
plt.imshow(arr)

# %%
arr[15,10]
# Out:
# 0.0

# %%
arr.shape
# Out:
# (100, 100)
